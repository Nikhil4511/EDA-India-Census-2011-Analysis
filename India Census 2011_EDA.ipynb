# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\npal1\OneDrive\Desktop\All_CSV File\6. India Census 2011.csv")
df
# Out:
#      District_code                   State_name              District_name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population    Male  Female  Literate  Workers  Male_Workers  \
# ...

# %%
df.style.set_caption("India Census 2011 DataSet")

# %% [markdown]
# ## Top Ten Rows

# %%
df.head(10)
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
# 5              6  JAMMU AND KASHMIR       Rajouri      642415  345351  297064
# 6              7  JAMMU AND KASHMIR        Kathua      616435  326109  290326
# 7              8  JAMMU AND KASHMIR      Baramula     1008039  534733  473306
# 8              9  JAMMU AND KASHMIR     Bandipore      392232  207680  184552
# 9             10  JAMMU AND KASHMIR      Srinagar     1236829  651124  585705
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# ...

# %%
df.shape # for rows and columns
# Out:
# (640, 25)

# %% [markdown]
# ##  10 Bottom rows

# %%
df.tail(10)
# Out:
#      District_code                   State_name              District_name  \
# 630            631                   TAMIL NADU                Krishnagiri
# 631            632                   TAMIL NADU                 Coimbatore
# 632            633                   TAMIL NADU                   Tiruppur
# 633            634                  PONDICHERRY                      Yanam
# 634            635                  PONDICHERRY                PONDICHERRY
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population     Male   Female  Literate  Workers  Male_Workers  \
# 630     1879809   960232   919577   1187958   877779        561634
# ...

# %% [markdown]
# ## Checking for data info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   District_code         640 non-null    int64
#  1   State_name            640 non-null    object
#  2   District_name         640 non-null    object
#  3   Population            640 non-null    int64
#  4   Male                  640 non-null    int64
#  5   Female                640 non-null    int64
#  6   Literate              640 non-null    int64
#  7   Workers               640 non-null    int64
#  8   Male_Workers          640 non-null    int64
#  9   Female_Workers        640 non-null    int64
#  10  Cultivator_Workers    640 non-null    int64
#  11  Agricultural_Workers  640 non-null    int64
#  12  Household_Workers     640 non-null    int64
#  13  Hindus                640 non-null    int64
#  14  Muslims               640 non-null    int64
# ...

# %% [markdown]
# ## check for null values

# %%
df.isnull().sum()
# Out:
# District_code           0
# State_name              0
# District_name           0
# Population              0
# Male                    0
# Female                  0
# Literate                0
# Workers                 0
# Male_Workers            0
# Female_Workers          0
# Cultivator_Workers      0
# Agricultural_Workers    0
# Household_Workers       0
# Hindus                  0
# Muslims                 0
# Christians              0
# Sikhs                   0
# Buddhists               0
# Jains                   0
# Secondary_Education     0
# Higher_Education        0
# Graduate_Education      0
# Age_Group_0_29          0
# Age_Group_30_49         0
# Age_Group_50            0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## India's Whole Population analysis according to 2011

# %%
print("Total Population in India according to 2011 :",df['Population'].sum())
# Out:
# Total Population in India according to 2011 : 1210854977

# %%
df.describe()
# Out:
#        District_code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#             Workers  Male_Workers  Female_Workers  Cultivator_Workers  \
# count  6.400000e+02  6.400000e+02    6.400000e+02        6.400000e+02
# mean   7.529514e+05  5.186561e+05    2.342953e+05        1.856387e+05
# ...

# %% [markdown]
# ## Checking for duplicate values

# %%
# check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
df.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %%
df.set_index('District_code', inplace=True)
df
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %%
df.columns
# Out:
# Index(['District_code', 'State_name', 'District_name', 'Population', 'Male',
#        'Female', 'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %% [markdown]
# ## Cheaking for all states value counts

# %%
df["State_name"].value_counts()
# Out:
# State_name
# UTTAR PRADESH                  71
# MADHYA PRADESH                 50
# BIHAR                          38
# MAHARASHTRA                    35
# RAJASTHAN                      33
# TAMIL NADU                     32
# KARNATAKA                      30
# ORISSA                         30
# ASSAM                          27
# GUJARAT                        26
# JHARKHAND                      24
# ANDHRA PRADESH                 23
# JAMMU AND KASHMIR              22
# HARYANA                        21
# PUNJAB                         20
# WEST BENGAL                    19
# CHHATTISGARH                   18
# ARUNACHAL PRADESH              16
# KERALA                         14
# UTTARAKHAND                    13
# HIMACHAL PRADESH               12
# NAGALAND                       11
# MANIPUR                         9
# NCT OF DELHI                    9
# MIZORAM                         8
# MEGHALAYA                       7
# TRIPURA                         4
# ...

# %% [markdown]
# ## Show the states wise details

# %%
df[df['State_name'].isin(['UTTAR PRADESH'])].head(10)
# Out:
#                   State_name        District_name  Population     Male  \
# District_code
# 132            UTTAR PRADESH           Saharanpur     3466382  1834106
# 133            UTTAR PRADESH        Muzaffarnagar     4143512  2193434
# 134            UTTAR PRADESH               Bijnor     3682713  1921215
# 135            UTTAR PRADESH            Moradabad     4772006  2503186
# 136            UTTAR PRADESH               Rampur     2335819  1223889
# 137            UTTAR PRADESH  Jyotiba Phule Nagar     1840221   963449
# 138            UTTAR PRADESH               Meerut     3443689  1825743
# 139            UTTAR PRADESH              Baghpat     1303048   700070
# 140            UTTAR PRADESH            Ghaziabad     4681645  2488834
# 141            UTTAR PRADESH  Gautam Buddha Nagar     1648115   890214
#
#                 Female  Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 132            1632276   2077108  1037344        911136          126208
# ...

# %% [markdown]
# ## Cheaking for all districts value counts

# %%
df["District_name"].value_counts()
# Out:
# District_name
# Raigarh          2
# Hamirpur         2
# Aurangabad       2
# Bijapur          2
# Bilaspur         2
#                 ..
# Muzaffarpur      1
# Gopalganj        1
# Siwan            1
# Saran            1
# South Andaman    1
# Name: count, Length: 634, dtype: int64

# %% [markdown]
# ## Show the record related with the districts

# %%
df[df['District_name'].isin(['Hamirpur','Etawah','New Delhi'])]
# Out:
#                      State_name District_name  Population    Male  Female  \
# District_code
# 28             HIMACHAL PRADESH      Hamirpur      454768  217070  237698
# 94                 NCT OF DELHI     New Delhi      142004   77942   64062
# 161               UTTAR PRADESH        Etawah     1581810  845856  735954
# 168               UTTAR PRADESH      Hamirpur     1104285  593537  510748
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 28               358091   241931        118724          123207
# 94               114179    59541         46940           12601
# 161             1062003   506072        413713           92359
# 168              653299   443655        308527          135128
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 28                         147103  ...         243    591         95    293
# ...

# %% [markdown]
# ##  Calculate the Total number of Population states wise

# %%
df.groupby("State_name").Population.sum().sort_values(ascending = False)
# Out:
# State_name
# UTTAR PRADESH                  199812341
# MAHARASHTRA                    112374333
# BIHAR                          104099452
# WEST BENGAL                     91276115
# ANDHRA PRADESH                  84580777
# MADHYA PRADESH                  72626809
# TAMIL NADU                      72147030
# RAJASTHAN                       68548437
# KARNATAKA                       61095297
# GUJARAT                         60439692
# ORISSA                          41974218
# KERALA                          33406061
# JHARKHAND                       32988134
# ASSAM                           31205576
# PUNJAB                          27743338
# CHHATTISGARH                    25545198
# HARYANA                         25351462
# NCT OF DELHI                    16787941
# JAMMU AND KASHMIR               12541302
# UTTARAKHAND                     10086292
# HIMACHAL PRADESH                 6864602
# TRIPURA                          3673917
# ...

# %% [markdown]
# ##  Calculate the Total number of Population District wise with there district code

# %%
df.groupby("District_code").Population.sum().sort_values(ascending = False)
# Out:
# District_code
# 517    11060148
# 337    10009781
# 572     9621551
# 521     9429408
# 518     9356962
#          ...
# 638       36842
# 252       35320
# 25        31564
# 260       21167
# 257        8004
# Name: Population, Length: 640, dtype: int64

# %%
df.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %% [markdown]
# ## Total number of Population with different religions

# %%
print("Total number of [Hindus Muslims Christians Sikhs] population in individual states")
print()
# Grouping by 'State_name' and summing 'Hindus' and 'Christians' for each state
state_population = df.groupby('State_name')[['Hindus', 'Muslims', 'Christians', 'Sikhs']].sum().sort_values(by='Hindus', ascending=False)

print(state_population)
# Out:
# Total number of [Hindus Muslims Christians Sikhs] population in individual states
#
#                                 Hindus   Muslims  Christians     Sikhs
# State_name
# UTTAR PRADESH                159312654  38483967      356448    643500
# MAHARASHTRA                   89703057  12971152     1080073    223247
# BIHAR                         86078686  17557809      129247     23779
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# MADHYA PRADESH                66007121   4774695      213282    151412
# WEST BENGAL                   64385546  24654825      658618     63523
# TAMIL NADU                    63188168   4229479     4418331     14601
# RAJASTHAN                     60657103   6215377       96430    872930
# GUJARAT                       53533988   5846761      316178     58246
# KARNATAKA                     51317472   7893065     1142647     28773
# ORISSA                        39300341    911670     1161708     21991
# ...

# %% [markdown]
# ## Age group for different types of ages

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df.groupby('State_name')[['Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50']].sum().sort_values(by= 'Age_Group_0_29', ascending = False)
# Out:
#                              Age_Group_0_29  Age_Group_30_49  Age_Group_50
# State_name
# UTTAR PRADESH                     126507123         44192083      27491073
# BIHAR                              66930323         22949064      13816563
# MAHARASHTRA                        61782561         30272010      19912066
# WEST BENGAL                        50551737         25343015      15268912
# ANDHRA PRADESH                     45815669         23148452      14845225
# MADHYA PRADESH                     44264116         17814066      10465765
# RAJASTHAN                          42814434         15938006       9526395
# TAMIL NADU                         36336584         21429281      14314360
# GUJARAT                            34370917         16291242       9538689
# KARNATAKA                          33676315         16740325      10632806
# ORISSA                             23359384         11179683       7315980
# ...

# %% [markdown]
# ## Age group district Wise

# %%
df.groupby('District_name')[['Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50']].sum().sort_values(by= 'Age_Group_0_29', ascending = False)
# Out:
#                             Age_Group_0_29  Age_Group_30_49  Age_Group_50
# District_name
# Thane                              6184519          3241888       1579921
# Bangalore                          5275666          2909575       1424195
# Pune                               5184734          2624165       1586132
# North Twenty Four Parganas         5104876          2968996       1921143
# Mumbai Suburban                    4936360          2812001       1575566
# ...                                    ...              ...           ...
# Mahe                                 19760            12543          9428
# Nicobars                             18786            12088          5922
# Lahul AND Spiti                      15928             9181          6200
# Anjaw                                13913             4755          2456
# Dibang Valley                         5113             2088           786
#
# [634 rows x 3 columns]

# %% [markdown]
# ## Getting min value for each group

# %%
min_value = df.groupby('District_name')[['Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50']].sum().min()
min_value
# Out:
# Age_Group_0_29     5113
# Age_Group_30_49    2088
# Age_Group_50        786
# dtype: int64

# %% [markdown]
# ## Getting max value for each group

# %%
max_values = df.groupby('District_name')[['Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50']].sum().max()
max_values
# Out:
# Age_Group_0_29     6184519
# Age_Group_30_49    3241888
# Age_Group_50       1921143
# dtype: int64

# %% [markdown]
# ## how many male worker in states

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %%
State_name = df['State_name']
print(State_name)
# Out:
# District_code
# 1                JAMMU AND KASHMIR
# 2                JAMMU AND KASHMIR
# 3                JAMMU AND KASHMIR
# 4                JAMMU AND KASHMIR
# 5                JAMMU AND KASHMIR
#                   ...
# 636                    PONDICHERRY
# 637                    PONDICHERRY
# 638    ANDAMAN AND NICOBAR ISLANDS
# 639    ANDAMAN AND NICOBAR ISLANDS
# 640    ANDAMAN AND NICOBAR ISLANDS
# Name: State_name, Length: 640, dtype: object

# %%
District_name = df['District_name']
print(District_name)
# Out:
# District_code
# 1                        Kupwara
# 2                         Badgam
# 3                    Leh(Ladakh)
# 4                         Kargil
# 5                          Punch
#                  ...
# 636                         Mahe
# 637                     Karaikal
# 638                     Nicobars
# 639    North  AND Middle Andaman
# 640                South Andaman
# Name: District_name, Length: 640, dtype: object

# %%
df['State_name'].unique()
# Out:
# array(['JAMMU AND KASHMIR', 'HIMACHAL PRADESH', 'PUNJAB', 'CHANDIGARH',
#        'UTTARAKHAND', 'HARYANA', 'NCT OF DELHI', 'RAJASTHAN',
#        'UTTAR PRADESH', 'BIHAR', 'SIKKIM', 'ARUNACHAL PRADESH',
#        'NAGALAND', 'MANIPUR', 'MIZORAM', 'TRIPURA', 'MEGHALAYA', 'ASSAM',
#        'WEST BENGAL', 'JHARKHAND', 'ORISSA', 'CHHATTISGARH',
#        'MADHYA PRADESH', 'GUJARAT', 'DAMAN AND DIU',
#        'DADRA AND NAGAR HAVELI', 'MAHARASHTRA', 'ANDHRA PRADESH',
#        'KARNATAKA', 'GOA', 'LAKSHADWEEP', 'KERALA', 'TAMIL NADU',
#        'PONDICHERRY', 'ANDAMAN AND NICOBAR ISLANDS'], dtype=object)

# %%
df[df.State_name == 'HARYANA']
# Out:
#               State_name District_name  Population    Male  Female  Literate  \
# District_code
# 69               HARYANA     Panchkula      561293  299679  261614    405318
# 70               HARYANA        Ambala     1128350  598703  529647    818025
# 71               HARYANA   Yamunanagar     1214205  646718  567487    832457
# 72               HARYANA   Kurukshetra      964655  510976  453679    646893
# 73               HARYANA       Kaithal     1074304  571003  503301    646529
# 74               HARYANA        Karnal     1505324  797712  707612    978013
# 75               HARYANA       Panipat     1205437  646857  558580    786599
# 76               HARYANA       Sonipat     1450001  781299  668702    998316
# 77               HARYANA          Jind     1334152  713006  621146    832758
# 78               HARYANA     Fatehabad      942011  495360  446651    557578
# 79               HARYANA         Sirsa     1295189  682582  612607    782897
# ...

# %% [markdown]
# ## Total Male in haryana

# %%
df[df['State_name'] == 'HARYANA']['Male'].sum()
# Out:
# 13494734

# %% [markdown]
# ## Total Male Worker in haryana

# %%
# print("Total Male Worker in = ")
df[df['State_name'] == 'HARYANA']['Male_Workers'].sum()
# Out:
# 6806636

# %%
print("These male are searching for Work :",13494734-6806636)
# Out:
# These male are searching for Work : 6688098

# %% [markdown]
# ## Uttar Pradesh

# %%
df[df.State_name == 'UTTAR PRADESH']
# Out:
#                   State_name                 District_name  Population  \
# District_code
# 132            UTTAR PRADESH                    Saharanpur     3466382
# 133            UTTAR PRADESH                 Muzaffarnagar     4143512
# 134            UTTAR PRADESH                        Bijnor     3682713
# 135            UTTAR PRADESH                     Moradabad     4772006
# 136            UTTAR PRADESH                        Rampur     2335819
# ...                      ...                           ...         ...
# 198            UTTAR PRADESH  Sant Ravidas Nagar (Bhadohi)     1578213
# 199            UTTAR PRADESH                      Mirzapur     2496970
# 200            UTTAR PRADESH                     Sonbhadra     1862559
# 201            UTTAR PRADESH                          Etah     1774480
# 202            UTTAR PRADESH               Kanshiram Nagar     1436719
#
#                   Male   Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %%
df[df['State_name'] == 'UTTAR PRADESH']['Male_Workers'].sum()
# Out:
# 49846762

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %% [markdown]
# ## Total Male and Female Workers in each state

# %%
df.groupby('State_name')[['Male','Male_Workers','Female','Female_Workers']].sum()#.sort_values(by='')
# Out:
#                                   Male  Male_Workers    Female  Female_Workers
# State_name
# ANDAMAN AND NICOBAR ISLANDS     202871        120889    177710           31646
# ANDHRA PRADESH                42442146      24185595  42138631        15237311
# ARUNACHAL PRADESH               713912        350273    669815          237384
# ASSAM                         15939443       8541560  15266133         3428130
# BIHAR                         54278157      25222189  49821295         9502798
# CHANDIGARH                      580663        328159    474787           75977
# CHHATTISGARH                  12832895       7133866  12712303         5046359
# DADRA AND NAGAR HAVELI          193760        119293    149949           37868
# DAMAN AND DIU                   150301        107434     92946           13837
# GOA                             739140        419536    719405          157712
# GUJARAT                       31491260      18000914  28948432         6766833
# ...

# %%
grouped_data = df.groupby('State_name')[['Male','Male_Workers']].sum()
grouped_data
# Out:
#                                   Male  Male_Workers
# State_name
# ANDAMAN AND NICOBAR ISLANDS     202871        120889
# ANDHRA PRADESH                42442146      24185595
# ARUNACHAL PRADESH               713912        350273
# ASSAM                         15939443       8541560
# BIHAR                         54278157      25222189
# CHANDIGARH                      580663        328159
# CHHATTISGARH                  12832895       7133866
# DADRA AND NAGAR HAVELI          193760        119293
# DAMAN AND DIU                   150301        107434
# GOA                             739140        419536
# GUJARAT                       31491260      18000914
# HARYANA                       13494734       6806636
# HIMACHAL PRADESH               3481873       2043373
# JAMMU AND KASHMIR              6640662       3195090
# JHARKHAND                     16930315       8424769
# KARNATAKA                     30966657      18270116
# ...

# %% [markdown]
# ## Individual states Male data

# %%
male_workers_State = grouped_data.loc['UTTAR PRADESH']
male_workers_State
# Out:
# Male            104480510
# Male_Workers     49846762
# Name: UTTAR PRADESH, dtype: int64

# %%
male_workers_State = grouped_data.loc['TRIPURA']
male_workers_State
# Out:
# Male            1874376
# Male_Workers    1045326
# Name: TRIPURA, dtype: int64

# %% [markdown]
# ## Individual states Female data

# %%
grouped_data = df.groupby('State_name')[['Female','Female_Workers']].sum()
grouped_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 grouped_data = df.groupby('State_name')[['Female','Female_Workers']].sum()
#       2 grouped_data
#
# NameError: name 'df' is not defined

# %%
Female_workers_State = grouped_data.loc['UTTAR PRADESH']
Female_workers_State
# Out:
# Female            95331831
# Female_Workers    15967953
# Name: UTTAR PRADESH, dtype: int64

# %%
Female_worker_State = grouped_data.loc['NCT OF DELHI']
print("Female Worker in Delhi")
Female_worker_State
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 Female_worker_State = grouped_data.loc['NCT OF DELHI']
#       2 print("Female in Delhi")
#       3 Female_worker_State
#
# NameError: name 'grouped_data' is not defined

# %% [markdown]
# ## District Wise Male_Worker and  Female_Worker data

# %%
df.groupby('District_name')[['Male','Male_Workers','Female','Female_Workers']].sum()
# Out:
#                   Male  Male_Workers   Female  Female_Workers
# District_name
# Adilabad       1369597        748939  1371642          574728
# Agra           2364953       1119701  2053844          270143
# Ahmadabad      3788051       2127547  3426174          467405
# Ahmadnagar     2342825       1300309  2200334          904281
# Aizawl          199270        104643   201039           69993
# ...                ...           ...      ...             ...
# Yadgir          590329        317135   583942          230561
# Yamunanagar     646718        342343   567487           46890
# Yanam            27301         14047    28325            2713
# Yavatmal       1419965        815475  1352383          540524
# Zunheboto        71217         41178    69540           38288
#
# [634 rows x 4 columns]

# %%
grouped_data = df.groupby('District_name')[['Male','Male_Workers']].sum()
grouped_data
# Out:
#                   Male  Male_Workers
# District_name
# Adilabad       1369597        748939
# Agra           2364953       1119701
# Ahmadabad      3788051       2127547
# Ahmadnagar     2342825       1300309
# Aizawl          199270        104643
# ...                ...           ...
# Yadgir          590329        317135
# Yamunanagar     646718        342343
# Yanam            27301         14047
# Yavatmal       1419965        815475
# Zunheboto        71217         41178
#
# [634 rows x 2 columns]

# %%
male_workers_district = grouped_data.loc['Agra']
male_workers_district
# Out:
# Male            2364953
# Male_Workers    1119701
# Name: Agra, dtype: int64

# %%
male_workers_district = grouped_data.loc['Yamunanagar']
male_workers_district
# Out:
# Male            646718
# Male_Workers    342343
# Name: Yamunanagar, dtype: int64

# %%
grouped_data = df.groupby('District_name')[['Female','Female_Workers']].sum()
grouped_data
# Out:
#                 Female  Female_Workers
# District_name
# Adilabad       1371642          574728
# Agra           2053844          270143
# Ahmadabad      3426174          467405
# Ahmadnagar     2200334          904281
# Aizawl          201039           69993
# ...                ...             ...
# Yadgir          583942          230561
# Yamunanagar     567487           46890
# Yanam            28325            2713
# Yavatmal       1352383          540524
# Zunheboto        69540           38288
#
# [634 rows x 2 columns]

# %%
female_workers_district = grouped_data.loc['Agra']
female_workers_district
# Out:
# Female            2053844
# Female_Workers     270143
# Name: Agra, dtype: int64

# %%
df
# Out:
#                                 State_name              District_name  \
# District_code
# 1                        JAMMU AND KASHMIR                    Kupwara
# 2                        JAMMU AND KASHMIR                     Badgam
# 3                        JAMMU AND KASHMIR                Leh(Ladakh)
# 4                        JAMMU AND KASHMIR                     Kargil
# 5                        JAMMU AND KASHMIR                      Punch
# ...                                    ...                        ...
# 636                            PONDICHERRY                       Mahe
# 637                            PONDICHERRY                   Karaikal
# 638            ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 639            ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 640            ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#                Population    Male  Female  Literate  Workers  Male_Workers  \
# District_code
# ...

# %% [markdown]
# ## Not Working Male in there districts

# %%
df['Not_working_Males']=df['Male']-df['Male_Workers']
df['Not_working_Males']
# Out:
# District_code
# 1      283291
# 2      235463
# 3       25706
# 4       37946
# 5      134222
#         ...
# 636     10050
# 637     44670
# 638      8013
# 639     24249
# 640     49720
# Name: Not_working_Males, Length: 640, dtype: int64

# %%
df.shape
# Out:
# (640, 25)

# %% [markdown]
# ## Not working female in there districts

# %%
df['Not_working_Males']=df['Female']-df['Female_Workers']
df['Not_working_Males']
# Out:
# District_code
# 1      357999
# 2      303416
# 3       32702
# 4       50983
# 5      181220
#         ...
# 636     19964
# 637     87251
# 638     11704
# 639     42769
# 640     91591
# Name: Not_working_Males, Length: 640, dtype: int64

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50',
#        'Not_working_Males'],
#       dtype='object')

# %% [markdown]
# # Visualizations---  📊📈

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %% [markdown]
# ## Line Plot for Population

# %%
plt.figure(figure = (4,5))
sns.lineplot(y='Population',x='State_name',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
sns.displot(df["Population"])
plt.show()

# %%
df.head()
# Out:
#    District_code         State_name District_name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 0    439654   229064        190899           38165  ...        1700   5600
# 1    335649   214866        162578           52288  ...        1489   5559
# 2     93770    75079         53265           21814  ...         658   1092
# 3     86236    51873         39839           12034  ...         604   1171
# 4    261724   161393        117677           43716  ...         958  11188
#
# ...

# %% [markdown]
# ## Top Ten Populated States by India Census 2011

# %%
df.groupby('State_name')['Population'].sum().sort_values(ascending=False)[:10].plot(kind='bar',color='r',)
plt.title("Top 10 Populated States ")
plt.xticks(rotation=90)
ax = sns.countplot(x ='State_name',data = df)
ax.bar_label(ax.containers[0])
plt.xlabel("States")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# # District Code wise Population

# %%
grouped_data = df.groupby('District_code')[['Male','Female']].sum()
# Create the plot
plt.figure(figure = (10,20))
grouped_data[0:15].plot(kind='bar', figsize=(12, 8), color=['skyblue', 'lightgreen'])
plt.title("Male and Female Population Graph",fontsize = 20)
plt.xlabel("District Code",fontsize = 16)
plt.ylabel("Population",fontsize = 16)
plt.legend(title="Population", fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# ## Male in each state vs Male_Worker

# %%
df.groupby('State_name')[['Male','Male_Workers']].sum()[10:-2].plot(kind='bar')#Male in each state Vs Male_Workers for each state
plt.title("Male in each state vs Male_Workers")
plt.show()

# %%
df.head()
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 4              JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 5              JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
# 4                 86236    51873         39839           12034
# 5                261724   161393        117677           43716
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# ...

# %% [markdown]
# ## Female and Female_Worker in each states

# %%
plt.figure(figure = (10,20))

df.groupby('State_name')[['Female','Female_Workers']].sum()[1:].plot(kind='bar')#Male in each state Vs Male_Workers for each state
plt.title("Female in each state vs Female_Workers")
plt.legend(title="Worker", fontsize=6)

plt.show()

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %%
plt.figure(figure = (10,20))

df.groupby('State_name')[['Female','Female_Workers','Cultivator_Workers','Agricultural_Workers','Household_Workers']].sum()[1:15].plot(kind='bar')#Male in each state Vs Male_Workers for each state
plt.title("Female_Workers")
plt.legend(title=" Female Worker", fontsize=6)

plt.show()

# %%
grouped_data = df.groupby('State_name')[['Male','Male_Workers','Cultivator_Workers','Agricultural_Workers','Household_Workers']].sum()
plt.figure(figure = (12,8))
grouped_data[1:15].plot(kind='bar', figsize=(12, 8), color=['m', 'lightgreen', 'salmon','b','black'])
plt.title("Male Workers", fontsize=16)
plt.xlabel("Male Workers Categories", fontsize=14)
plt.ylabel("Count of Male_Workers", fontsize=14)
plt.xticks(rotation=90, fontsize=12)  # Rotate x-axis labels for better visibility
plt.legend(title="Male_Workers", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Checking for Male Education Status

# %%
df.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %%
df.groupby('Male')[['Secondary_Education','Higher_Education','Graduate_Education']].sum()#Male in each state Vs Male_Workers for each state
grouped_data[:20].plot(kind='bar', figsize=(12, 8), color=['m', 'lightgreen', 'salmon'])
plt.title("Male Education Levels in Each State", fontsize=16)
plt.xlabel("Male Categories", fontsize=14)
plt.ylabel("Count of Education Levels", fontsize=14)
plt.xticks(rotation=90, fontsize=12)  # Rotate x-axis labels for better visibility
plt.legend(title="Education Levels", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for reference
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Female Education Status

# %%
# Grouping the data and summing it
grouped_data = df.groupby('Female')[['Secondary_Education', 'Higher_Education', 'Graduate_Education']].sum()

# Creating the plot
plt.figure(figsize=(12, 8))  # Adjust figure size for clarity
grouped_data[:20].plot(kind='bar', figsize=(12, 8), color=['skyblue', 'lightgreen', 'salmon'])
plt.title("Female Education Levels in Each State", fontsize=16)
plt.xlabel("Female Categories", fontsize=14)
plt.ylabel("Count of Education Levels", fontsize=14)
plt.xticks(rotation=90, fontsize=12)  # Rotate x-axis labels for better visibility
plt.legend(title="Education Levels", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add gridlines for reference
plt.tight_layout()  # Ensure everything fits within the plot area

# Display the plot
plt.show()

# %%
plt.scatter(df['Secondary_Education'], df['Graduate_Education'],s=40, c='blue', alpha=0.5, edgecolors='black', linewidths=1)
plt.title("Relation between Secondary_Education Vs Graduate_Education")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
df.head(3)
# Out:
#                       State_name District_name  Population    Male  Female  \
# District_code
# 1              JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 2              JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 3              JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
#
#                Literate  Workers  Male_Workers  Female_Workers  \
# District_code
# 1                439654   229064        190899           38165
# 2                335649   214866        162578           52288
# 3                 93770    75079         53265           21814
#
#                Cultivator_Workers  ...  Christians  Sikhs  Buddhists  Jains  \
# District_code                      ...
# 1                           34680  ...        1700   5600         66     39
# 2                           55299  ...        1489   5559         47      6
# 3                           20869  ...         658   1092      88635    103
#
# ...

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Population', 'Male', 'Female',
#        'Literate', 'Workers', 'Male_Workers', 'Female_Workers',
#        'Cultivator_Workers', 'Agricultural_Workers', 'Household_Workers',
#        'Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists', 'Jains',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50'],
#       dtype='object')

# %% [markdown]
# ## Male age group between 0_to_50

# %%
grouped_data = df.groupby('State_name')[['Age_Group_0_29','Age_Group_30_49','Age_Group_50']].sum()#Male in each state Vs Male_Workers for each state
plt.figure(figure = (12,8))
grouped_data[0:35].plot(kind='bar', figsize=(12, 8), color=['yellow', 'lightgreen', 'salmon'])
plt.title("Male Age Group Between 0_to_50", fontsize=16)
plt.xlabel("Age Group", fontsize=14)
plt.ylabel("Count of Age Group", fontsize=14)
plt.xticks(rotation=90, fontsize=12) 
plt.legend(title="Age Group", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)  
plt.tight_layout()
plt.show()

# 21 age group ke 800000
# 41 age group ke 1.75
# 50 age group ke 550000

# %% [markdown]
# # hist plot

# %%
df.hist(figsize=(20,20),color='blue') 
plt.show()

# %%
df.groupby('State_name')['Population'].sum().sort_values(ascending=False)[0:10].plot.pie(autopct='%1.1f%%', startangle=45,labeldistance=1.1,
                                                                                        radius=1.01,wedgeprops={"linewidth":5})
plt.xticks(rotation=45, fontsize=12)
# Out:
# (array([], dtype=float64), [])

# %%
df.dtypes
# Out:
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %%
df2=df.drop(['State_name','District_name'],axis=1) #heatmap works only on numerical values .
corr_matrix = df2.corr()

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=.1)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.kdeplot(df['Population'],color='blue',fill=True,shade=True)
plt.title('Population Age Distribution(Density Plot)')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\npal1\AppData\Local\Temp\ipykernel_15284\3058320304.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Population'],color='blue',fill=True,shade=True)
